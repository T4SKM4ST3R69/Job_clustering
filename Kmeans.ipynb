# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
import pickle


# 1. Scrape Function
def scrape_karkidi_jobs(keywords=["data scientist"], pages=2):
    headers = {'User-Agent': 'Mozilla/5.0'}
    base_url = "https://www.karkidi.com/Find-Jobs/{page}/all/India?search={query}"
    jobs_list = []

    for keyword in keywords:
        for page in range(1, pages + 1):
            url = base_url.format(page=page, query=keyword.replace(' ', '%20'))
            print(f"Scraping page {page} for '{keyword}'...")
            response = requests.get(url, headers=headers)
            soup = BeautifulSoup(response.content, "html.parser")

            job_blocks = soup.find_all("div", class_="ads-details")
            for job in job_blocks:
                try:
                    title = job.find("h4").get_text(strip=True)
                    company = job.find("a", href=lambda x: x and "Employer-Profile" in x).get_text(strip=True)
                    location = job.find("p").get_text(strip=True)
                    experience = job.find("p", class_="emp-exp").get_text(strip=True)
                    key_skills_tag = job.find("span", string="Key Skills")
                    skills = key_skills_tag.find_next("p").get_text(strip=True) if key_skills_tag else ""
                    summary_tag = job.find("span", string="Summary")
                    summary = summary_tag.find_next("p").get_text(strip=True) if summary_tag else ""

                    jobs_list.append({
                        "Keyword": keyword,
                        "Title": title,
                        "Company": company,
                        "Location": location,
                        "Experience": experience,
                        "Summary": summary,
                        "Skills": skills
                    })
                except Exception as e:
                    print(f"Error parsing job block: {e}")
                    continue

            time.sleep(1)  # Be polite

    return pd.DataFrame(jobs_list)

if __name__ == "__main__":
    df_jobs = scrape_karkidi_jobs()
# Out:
# Scraping page 1 for 'data scientist'...
# Scraping page 2 for 'data scientist'...

# %%
display(df_jobs)
# Out:
#            Keyword                                              Title  \
# 0   data scientist   Principal Product Manager - Growth, Poe (Remote)
# 1   data scientist          Machine Learning Physical Design Engineer
# 2   data scientist  Staff Software Engineer - Monetization, Poe (R...
# 3   data scientist  Staff Backend Engineer - Bot Creator Ecosystem...
# 4   data scientist  Senior Backend Engineer - Bot Creator Ecosyste...
# 5   data scientist                         Data Scientist Lead - AIML
# 6   data scientist          Applied AI ML Director - Machine Learning
# 7   data scientist                            Senior Product Designer
# 8   data scientist                         Manager - Machine Learning
# 9   data scientist                                     Data Scientist
# 10  data scientist   Principal Product Manager - Growth, Poe (Remote)
# 11  data scientist          Machine Learning Physical Design Engineer
# 12  data scientist  Staff Software Engineer - Monetization, Poe (R...
# 13  data scientist  Staff Backend Engineer - Bot Creator Ecosystem...
# 14  data scientist  Senior Backend Engineer - Bot Creator Ecosyste...
# 15  data scientist                         Data Scientist Lead - AIML
# 16  data scientist          Applied AI ML Director - Machine Learning
# 17  data scientist                            Senior Product Designer
# 18  data scientist                         Manager - Machine Learning
# 19  data scientist                                     Data Scientist
#
#            Company                     Location  Experience  \
# 0      Quora, Inc.                        India    6-8 year
# 1           Google  Bengaluru, Karnataka, India    4-6 year
# 2      Quora, Inc.                        India   8-10 year
# 3      Quora, Inc.                        India   8-10 year
# 4      Quora, Inc.                        India    6-8 year
# 5   JPMorgan Chase  Bengaluru, Karnataka, India    6-8 year
# 6   JPMorgan Chase  Hyderabad, Telangana, India  12-14 year
# 7       Observe.AI  Bangalore, Karnataka, India   8-10 year
# 8       Observe.AI  Bangalore, Karnataka, India   8-10 year
# 9          Spotify   Mumbai, Maharashtra, India    6-8 year
# 10     Quora, Inc.                        India    6-8 year
# 11          Google  Bengaluru, Karnataka, India    4-6 year
# 12     Quora, Inc.                        India   8-10 year
# 13     Quora, Inc.                        India   8-10 year
# 14     Quora, Inc.                        India    6-8 year
# 15  JPMorgan Chase  Bengaluru, Karnataka, India    6-8 year
# 16  JPMorgan Chase  Hyderabad, Telangana, India  12-14 year
# 17      Observe.AI  Bangalore, Karnataka, India   8-10 year
# 18      Observe.AI  Bangalore, Karnataka, India   8-10 year
# 19         Spotify   Mumbai, Maharashtra, India    6-8 year
#
#                                               Summary  \
# 0   About Quora:Quora’s mission is to grow and sha...
# 1   Minimum qualifications:Bachelor's degree in El...
# 2   About Quora:Quora’s mission is to grow and sha...
# 3   About Quora:Quora’s mission is to grow and sha...
# 4   About Quora:Quora’s mission is to grow and sha...
# 5   We have an opportunity to impact your career a...
# 6   Elevate your career as the Director of Machine...
# 7   Observe.AI is transforming customer service wi...
# 8   Observe.AI is transforming customer service wi...
# 9   We are looking for a Data Scientist to join th...
# 10  About Quora:Quora’s mission is to grow and sha...
# 11  Minimum qualifications:Bachelor's degree in El...
# 12  About Quora:Quora’s mission is to grow and sha...
# 13  About Quora:Quora’s mission is to grow and sha...
# 14  About Quora:Quora’s mission is to grow and sha...
# 15  We have an opportunity to impact your career a...
# 16  Elevate your career as the Director of Machine...
# 17  Observe.AI is transforming customer service wi...
# 18  Observe.AI is transforming customer service wi...
# 19  We are looking for a Data Scientist to join th...
#
#                                                Skills
# 0   Aartificial intelligence,Data Analytics,Data s...
# 1   Aartificial intelligence,Algorithms,Data struc...
# 2   Aartificial intelligence,Analytical and Proble...
# 3   Aartificial intelligence,API,Data science tech...
# 4   Aartificial intelligence,API,Data science tech...
# 5   Aartificial intelligence,Data science techniqu...
# 6   Aartificial intelligence,AWS,Azure,Google Clou...
# 7   Design,Leadership Skill,Machine learning techn...
# 8   Aartificial intelligence,Large Language Models...
# 9   Amazon RedShift,Apache Hadoop,Data science tec...
# 10  Aartificial intelligence,Data Analytics,Data s...
# 11  Aartificial intelligence,Algorithms,Data struc...
# 12  Aartificial intelligence,Analytical and Proble...
# 13  Aartificial intelligence,API,Data science tech...
# 14  Aartificial intelligence,API,Data science tech...
# 15  Aartificial intelligence,Data science techniqu...
# 16  Aartificial intelligence,AWS,Azure,Google Clou...
# 17  Design,Leadership Skill,Machine learning techn...
# 18  Aartificial intelligence,Large Language Models...
# 19  Amazon RedShift,Apache Hadoop,Data science tec...

# %%
# 2. Clean and Vectorize Skills
# Define tokenizer outside to make it pickleable
def custom_tokenizer(text):
    return [token.strip() for token in text.split(',') if token.strip()]

def preprocess_and_vectorize_skills(df):
    df = df.copy()
    df["Skills"] = df["Skills"].fillna("").str.lower().str.replace(r'[^a-zA-Z, ]', '', regex=True)
    tfidf = TfidfVectorizer(tokenizer=custom_tokenizer, lowercase=True)
    X = tfidf.fit_transform(df["Skills"])
    return X, tfidf

# %%
# 3. Determine Optimal Clusters using Silhouette Score
def find_optimal_k(X, k_range=range(2, 10)):
    best_score = -1
    best_k = 2
    for k in k_range:
        kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
        labels = kmeans.fit_predict(X)
        score = silhouette_score(X, labels)
        print(f"Silhouette Score for k={k}: {score:.4f}")
        if score > best_score:
            best_score = score
            best_k = k
    print(f"\nBest k based on silhouette score: {best_k}")
    return best_k

# %%
# 4. Cluster and Save Models
def cluster_and_save(X, df, tfidf, k):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    df["Cluster"] = kmeans.fit_predict(X)

    # Save the model and vectorizer
    joblib.dump(kmeans, "kmeans_model.joblib")
    joblib.dump(tfidf, "tfidf_vectorizer.joblib")
    df.to_csv("clustered_jobs.csv", index=False)

    print("✅ Model and vectorizer saved. Clustered data exported to 'clustered_jobs.csv'")
    return df

# %%
# 5. Full Pipeline
def main():

    # Preprocess & vectorize
    X, tfidf = preprocess_and_vectorize_skills(df_jobs)

    # Find best number of clusters
    best_k = find_optimal_k(X)

    # Cluster and save
    clustered_df = cluster_and_save(X, df_jobs, tfidf, best_k)

    print(clustered_df[["Title", "Skills", "Cluster"]].head())

if __name__ == "__main__":
    main()
# Out:
# Silhouette Score for k=2: 0.2069
# Silhouette Score for k=3: 0.2892
# Silhouette Score for k=4: 0.4250
# Silhouette Score for k=5: 0.5557
# Silhouette Score for k=6: 0.6802
# Silhouette Score for k=7: 0.8033
# Silhouette Score for k=8: 0.9343
# Silhouette Score for k=9: 1.0000
#
# Best k based on silhouette score: 9
# ✅ Model and vectorizer saved. Clustered data exported to 'clustered_jobs.csv'
#                                                Title  \
# 0   Principal Product Manager - Growth, Poe (Remote)
# 1          Machine Learning Physical Design Engineer
# 2  Staff Software Engineer - Monetization, Poe (R...
# 3  Staff Backend Engineer - Bot Creator Ecosystem...
# 4  Senior Backend Engineer - Bot Creator Ecosyste...
#
#                                               Skills  Cluster
# 0  Aartificial intelligence,Data Analytics,Data s...        5
# 1  Aartificial intelligence,Algorithms,Data struc...        4
# 2  Aartificial intelligence,Analytical and Proble...        7
# 3  Aartificial intelligence,API,Data science tech...        1
# 4  Aartificial intelligence,API,Data science tech...        1
